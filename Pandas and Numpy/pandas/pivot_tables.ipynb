# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv("../Datas/data.csv", index_col=0)

# %%
data.head()
# Out:
#        Country                           Region  Happiness Rank  \
# 0  Afghanistan                    Southern Asia           153.0
# 1      Albania       Central and Eastern Europe            95.0
# 2      Algeria  Middle East and Northern Africa            68.0
# 3       Angola               Sub-Saharan Africa           137.0
# 4    Argentina      Latin America and Caribbean            30.0
#
#    Happiness Score  Economy (GDP per Capita)   Family  \
# 0            3.575                   0.31982  0.30285
# 1            4.959                   0.87867  0.80434
# 2            5.605                   0.93929  1.07772
# 3            4.033                   0.75778  0.86040
# 4            6.574                   1.05351  1.24823
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.30335  0.23414                        0.09719
# 1                   0.81325  0.35733                        0.06413
# ...

# %% [markdown]
# ## Sort rows on the basis of Year and happienss

# %% [raw]
# Sorting table in ascending order with key year and in descending order with key Happiness Rank

# %%
data.sort_values(['Year', 'Happiness Rank'], ascending=[True, False], inplace=True)

# %%
data
# Out:
#                       Country                           Region  \
# 148                      Togo               Sub-Saharan Africa
# 22                    Burundi               Sub-Saharan Africa
# 142                     Syria  Middle East and Northern Africa
# 14                      Benin               Sub-Saharan Africa
# 122                    Rwanda               Sub-Saharan Africa
# 0                 Afghanistan                    Southern Asia
# 21               Burkina Faso               Sub-Saharan Africa
# 68                Ivory Coast               Sub-Saharan Africa
# 54                     Guinea               Sub-Saharan Africa
# 27                       Chad               Sub-Saharan Africa
# 26   Central African Republic               Sub-Saharan Africa
# 86                 Madagascar               Sub-Saharan Africa
# 146                  Tanzania               Sub-Saharan Africa
# 23                   Cambodia                Southeastern Asia
# ...

# %%
#get size of data row X column
data.shape
# Out:
# (495, 12)

# %%
#check for null value in data
print("Null value in data : ")
print(data.isnull().any().any())
print()
print('Null value in each column of data: ')
#check for null value in each column of data
print(data.isnull().any())
# Out:
# Null value in data :
# True
#
# Null value in each column of data:
# Country                          False
# Region                           False
# Happiness Rank                    True
# Happiness Score                   True
# Economy (GDP per Capita)          True
# Family                            True
# Health (Life Expectancy)          True
# Freedom                           True
# Trust (Government Corruption)     True
# Generosity                        True
# Dystopia Residual                 True
# Year                             False
# dtype: bool

# %%
#Short stat nature of data
data.describe()
# Out:
#        Happiness Rank  Happiness Score  Economy (GDP per Capita)      Family  \
# count      470.000000       470.000000                470.000000  470.000000
# mean        78.829787         5.370728                  0.927830    0.990347
# std         45.281408         1.136998                  0.415584    0.318707
# min          1.000000         2.693000                  0.000000    0.000000
# 25%         40.000000         4.509000                  0.605292    0.793000
# 50%         79.000000         5.282500                  0.995439    1.025665
# 75%        118.000000         6.233750                  1.252443    1.228745
# max        158.000000         7.587000                  1.870766    1.610574
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                470.000000  470.000000                     470.000000
# mean                   0.579968    0.402828                       0.134790
# ...

# %%
data.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                   float64
# Happiness Score                  float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# Year                               int64
# dtype: object

# %%
#viewing number of rows in each column which does not have null value
data.count()
# Out:
# Country                          495
# Region                           495
# Happiness Rank                   470
# Happiness Score                  470
# Economy (GDP per Capita)         470
# Family                           470
# Health (Life Expectancy)         470
# Freedom                          470
# Trust (Government Corruption)    470
# Generosity                       470
# Dystopia Residual                470
# Year                             495
# dtype: int64

# %% [markdown]
# ## Categorized Data by Year and Region

# %%
#categorized data by year
pd.pivot_table(data, index='Year', values='Happiness Score')
# Out:
#       Happiness Score
# Year
# 2015         5.375734
# 2016         5.382185
# 2017         5.354019

# %%
#categorized data by region
pd.pivot_table(data, index='Region', values='Happiness Score')
# Out:
#                                  Happiness Score
# Region
# Australia and New Zealand               7.302500
# Central and Eastern Europe              5.371184
# Eastern Asia                            5.632333
# Latin America and Caribbean             6.069074
# Middle East and Northern Africa         5.387879
# North America                           7.227167
# Southeastern Asia                       5.364077
# Southern Asia                           4.590857
# Sub-Saharan Africa                      4.150957
# Western Europe                          6.693000

# %% [markdown]
# ## Creating a multi-index pivot table

# %%
#categorized data by region and year
pd.pivot_table(data, index=['Region', 'Year'], values='Happiness Score')
# Out:
#                                       Happiness Score
# Region                          Year
# Australia and New Zealand       2015         7.285000
#                                 2016         7.323500
#                                 2017         7.299000
# Central and Eastern Europe      2015         5.332931
#                                 2016         5.370690
#                                 2017         5.409931
# Eastern Asia                    2015         5.626167
#                                 2016         5.624167
#                                 2017         5.646667
# Latin America and Caribbean     2015         6.144682
#                                 2016         6.101750
#                                 2017         5.957818
# Middle East and Northern Africa 2015         5.406900
#                                 2016         5.386053
#                                 2017         5.369684
# North America                   2015         7.273000
# ...

# %%
pd.pivot_table(data, index= 'Region', columns='Year', values="Happiness Score")
# Out:
# Year                                 2015      2016      2017
# Region
# Australia and New Zealand        7.285000  7.323500  7.299000
# Central and Eastern Europe       5.332931  5.370690  5.409931
# Eastern Asia                     5.626167  5.624167  5.646667
# Latin America and Caribbean      6.144682  6.101750  5.957818
# Middle East and Northern Africa  5.406900  5.386053  5.369684
# North America                    7.273000  7.254000  7.154500
# Southeastern Asia                5.317444  5.338889  5.444875
# Southern Asia                    4.580857  4.563286  4.628429
# Sub-Saharan Africa               4.202800  4.136421  4.111949
# Western Europe                   6.689619  6.685667  6.703714

# %% [markdown]
# ## Visualizing the pivot table using plot()

# %%
pd.pivot_table(data, index= 'Region', columns= 'Year', values= "Happiness Score").plot(kind= 'bar', figsize=(25,10))
plt.ylabel("Happiness Rank")
# Out:
# Text(0, 0.5, 'Happiness Rank')

# %% [markdown]
# ## Manipulating the data using aggfunc (aggfunc's default value is mean)

# %%
pd.pivot_table(data, index= 'Region', values= "Happiness Score",
               aggfunc= [np.mean, np.median, min, max, np.std])
# Out:
#                                            mean          median  \
#                                 Happiness Score Happiness Score
# Region
# Australia and New Zealand              7.302500          7.2995
# Central and Eastern Europe             5.371184          5.4010
# Eastern Asia                           5.632333          5.6545
# Latin America and Caribbean            6.069074          6.1265
# Middle East and Northern Africa        5.387879          5.3175
# North America                          7.227167          7.2175
# Southeastern Asia                      5.364077          5.2965
# Southern Asia                          4.590857          4.6080
# Sub-Saharan Africa                     4.150957          4.1390
# Western Europe                         6.693000          6.9070
#
#                                             min             max  \
#                                 Happiness Score Happiness Score
# Region
# ...

# %% [markdown]
# ## Applying a custom function to remove outliers

# %%
pd.pivot_table(data, index = 'Region', values="Happiness Score",
               aggfunc= [np.mean, min, max, np.std, lambda x: x.count()/3])
# Out:
#                                            mean             min  \
#                                 Happiness Score Happiness Score
# Region
# Australia and New Zealand              7.302500           7.284
# Central and Eastern Europe             5.371184           4.096
# Eastern Asia                           5.632333           4.874
# Latin America and Caribbean            6.069074           3.603
# Middle East and Northern Africa        5.387879           3.006
# North America                          7.227167           6.993
# Southeastern Asia                      5.364077           3.819
# Southern Asia                          4.590857           3.360
# Sub-Saharan Africa                     4.150957           2.693
# Western Europe                         6.693000           4.857
#
#                                             max             std  \
#                                 Happiness Score Happiness Score
# Region
# ...
